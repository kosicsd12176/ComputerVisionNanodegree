# %% [markdown]
# # Day and Night Image Classifier
# ---
#
# The day/night image dataset consists of 200 RGB color images in two categories: day and night. There are equal numbers of each example: 100 day images and 100 night images.
#
# We'd like to build a classifier that can accurately label these images as day or night, and that relies on finding distinguishing features between the two types of images!
#
# *Note: All images come from the [AMOS dataset](http://cs.uky.edu/~jacobs/datasets/amos/) (Archive of Many Outdoor Scenes).*

# %% [markdown]
# ### Import resources
#
# Before you get started on the project code, import the libraries and resources that you'll need.

# %%
import cv2 # computer vision library
import helpers

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %% [markdown]
# ## Training and Testing Data
# The 200 day/night images are separated into training and testing datasets.
#
# * 60% of these images are training images, for you to use as you create a classifier.
# * 40% are test images, which will be used to test the accuracy of your classifier.
#
# First, we set some variables to keep track of some where our images are stored:
#
#     image_dir_training: the directory where our training image data is stored
#     image_dir_test: the directory where our test image data is stored

# %%
# Image data directories
image_dir_training = "day_night_images/training/"
image_dir_test = "day_night_images/test/"

# %% [markdown]
# ## Load the datasets
#
# These first few lines of code will load the training day/night images and store all of them in a variable, `IMAGE_LIST`. This list contains the images and their associated label ("day" or "night").
#
# For example, the first image-label pair in `IMAGE_LIST` can be accessed by index:
# ``` IMAGE_LIST[0][:]```.

# %%
# Using the load_dataset function in helpers.py
# Load training data
IMAGE_LIST = helpers.load_dataset(image_dir_training)

# %% [markdown]
# ## Construct a `STANDARDIZED_LIST` of input images and output labels.
#
# This function takes in a list of image-label pairs and outputs a **standardized** list of resized images and numerical labels.

# %%
# Standardize all training images
STANDARDIZED_LIST = helpers.standardize(IMAGE_LIST)

# %% [markdown]
# ## Visualize the standardized data
#
# Display a standardized image from STANDARDIZED_LIST.

# %%
# Display a standardized image and its label

# Select an image by index
image_num = 190
selected_image = STANDARDIZED_LIST[image_num][0]
selected_label = STANDARDIZED_LIST[image_num][1]

# Display image and data about it
plt.imshow(selected_image)
print("Shape: "+str(selected_image.shape))
print("Label [1 = day, 0 = night]: " + str(selected_label))
# Out:
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 0

# %% [markdown]
# # Feature Extraction
#
# Create a feature that represents the brightness in an image. We'll be extracting the **average brightness** using HSV colorspace. Specifically, we'll use the V channel (a measure of brightness), add up the pixel values in the V channel, then divide that sum by the area of the image to get the average Value of the image.

# %% [markdown]
# ---
# ###  Find the average brightness using the V channel
#
# This function takes in a **standardized** RGB image and returns a feature (a single value) that represent the average level of brightness in the image. We'll use this value to classify the image as day or night.

# %%
# Find the average Value or brightness of an image
def avg_brightness(rgb_image):
    # Convert image to HSV
    hsv = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2HSV)

    # Add up all the pixel values in the V channel
    sum_brightness = np.sum(hsv[:,:,2])
    area = 600*1100.0  # pixels
    
    # find the avg
    avg = sum_brightness/area
    
    return avg

# %%
# Testing average brightness levels
# Look at a number of different day and night images and think about 
# what average brightness value separates the two types of images

# As an example, a "night" image is loaded in and its avg brightness is displayed
image_num = 160
test_im = STANDARDIZED_LIST[image_num][0]

avg = avg_brightness(test_im)
print('Avg brightness: ' + str(avg))
plt.imshow(test_im)
# Out:
# Avg brightness: 114.38604545454545

# %% [markdown]
# # Classification and Visualizing Error
#
# In this section, we'll turn our average brightness feature into a classifier that takes in a standardized image and returns a `predicted_label` for that image. This `estimate_label` function should return a value: 0 or 1 (night or day, respectively).

# %% [markdown]
# ---
# ### TODO: Build a complete classifier
#
# Set a threshold that you think will separate the day and night images by average brightness.

# %%
# This function should take in RGB image input
def estimate_label(rgb_image):
    
    ## TODO: extract average brightness feature from an RGB image 
    # Use the avg brightness feature to predict a label (0, 1)
    predicted_label = 0
    
    ## TODO: set the value of a threshold that will separate day and night images
    threshold = 115.
    ## TODO: Return the predicted_label (0 or 1) based on whether the avg is 
    # above or below the threshold
    if(threshold < avg_brightness(rgb_image)):
        predicted_label=1
        
    
    return predicted_label

# %%
## Test out your code by calling the above function and seeing 
# how some of your training data is classified
# Display a standardized image and its label

# Select an image by index
image_num = 0
for i in range(len(STANDARDIZED_LIST)):
    
    selected_image = STANDARDIZED_LIST[i][0]
    selected_label = STANDARDIZED_LIST[i][1]

    # Display image and data about it
    plt.imshow(selected_image)
    print("Shape: "+str(selected_image.shape))
    print("Label [1 = day, 0 = night]: " + str(selected_label) +" average brightness: "+ str(avg_brightness(selected_image))+ " predicted: " + str(estimate_label(selected_image)))
# Out:
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 175.09299242424242 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 192.90786666666668 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 132.13382272727273 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 199.7491909090909 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 109.94720303030303 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 200.02027575757575 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 112.14201515151515 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 103.30763636363636 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 198.09555757575757 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 104.23298181818181 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 197.4516621212121 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 105.50642424242425 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 195.10792575757577 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 108.41986818181819 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 195.45709242424243 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 107.65071363636363 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 196.82640303030303 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 191.27498787878787 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 111.65075757575758 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 181.73580606060605 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 110.29915454545454 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 187.70078636363635 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 109.03925757575757 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 188.28692575757574 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 110.25234848484848 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 189.62665757575758 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 107.35852878787878 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 191.53360757575757 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 105.60079242424243 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 103.3687287878788 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 145.51751212121212 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 163.8033484848485 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 160.2456484848485 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 123.61741969696969 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 158.01101212121213 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 152.30368636363636 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 157.36674393939393 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 104.06287272727273 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 155.31952424242425 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 129.84130303030304 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 138.8351893939394 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 129.66822878787877 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 149.41024242424243 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 129.73653636363636 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 129.23778181818182 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 128.06237424242426 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 111.25520151515151 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 127.94743484848485 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 154.03234242424242 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 141.0027212121212 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 125.83213484848484 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 155.15855 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 126.71624090909091 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 127.99821060606061 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 129.32292272727273 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 164.55517424242424 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 128.41493484848485 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 143.66287878787878 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 131.7711909090909 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 148.7741484848485 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 130.98634393939395 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 129.5273606060606 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 127.83165909090908 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 109.1135606060606 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 128.61035757575758 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 138.08745909090908 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 106.80848484848485 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 136.81613636363636 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 112.25848636363637 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 154.19991515151514 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 127.08735303030303 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 97.98974242424242 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 157.02129696969698 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 142.9224303030303 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 94.55345909090909 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 158.73422424242423 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 144.0751272727273 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 106.67311515151515 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 159.21086515151515 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 142.53216060606061 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 110.08663484848485 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 159.7777893939394 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 102.08629242424243 predicted: 0
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 115.03471363636363 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 133.3583909090909 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 120.24180454545454 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 136.9466424242424 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: 116.27588181818182 predicted: 1
# Shape: (600, 1100, 3)
# Label [1 = day, 0 = night]: 1 average brightness: